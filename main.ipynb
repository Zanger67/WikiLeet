# %% [markdown]
# # WikiLeet — Local Runner
#
# A thin wrapper around [main.py](main.py) for running the markdown generator locally, one pipeline stage at a time.
#
# All functionality lives in `main.py` — this notebook only calls its stage functions in the same order as `main.main()`. Path configuration is resolved by `env_config.py` from the `.env` file (a `.env` in the parent repo overrides the defaults).

# %%
import main
import env_config as config

config.load_environment()
config.init()

# %% [markdown]
# ## Options
#
# Mirrors the CLI flags of `python main.py` (see the module docstring in `main.py`).

# %%
RECALCULATE_ALL = False     # -r : regenerate every markdown even if its files are unchanged
NO_RECORD       = False     # -n : ignore the stored modification history and don't save it
USE_GIT_DATES   = False     # -g : date files via the git log (slow locally; meant for CI)

main.USE_GIT_DATES = USE_GIT_DATES

# %% [markdown]
# ## Discover submission files
#
# Scans the whole repo for solution files (plus contest folders) and notes/context files, keyed by their path from the README.

# %%
files = main.discover_submission_files()

# %% [markdown]
# ## File dates from the git log (optional)
#
# Only used with `USE_GIT_DATES` — bulk-parses creation/modification dates from the git history instead of the filesystem. Needed on GitHub Actions (checkouts reset file dates), but slow locally.

# %%
if USE_GIT_DATES :
    main.load_git_timestamps(files)

# %% [markdown]
# ## Question details and modification history
#
# Loads the official per-question details (title, difficulty, AC rate, topics, ...) from the question-data submodule, plus the stored file-modification history so unchanged questions aren't regenerated.

# %%
question_details  = main.retrieve_question_details()
file_latest_times = {} if (RECALCULATE_ALL or NO_RECORD) else main.load_file_times()

# %% [markdown]
# ## Parse solutions into question records
#
# Every solution/contest/context file is folded into one record per question. Questions with new or modified files are queued in `reprocess_markdown`.

# %%
question_data, reprocess_markdown = main.build_question_data(files,
                                                              question_details,
                                                              file_latest_times)

# %% [markdown]
# ## Tag list categories (NeetCode150, Blind75, ...)

# %%
main.apply_list_categories(question_data)

# %% [markdown]
# ## Per-question markdowns
#
# Writes one markdown page per new/updated question.

# %%
main.export_question_markdowns(question_data, reprocess_markdown, question_details)

# %% [markdown]
# ## Grouping markdowns
#
# The challenge pages run first — they also tag questions with the `Daily` / `Weekly Premium` categories shown in every other table.

# %%
additional_sorts = [
    f'- [Daily Questions](<{main.export_daily_markdown(question_data)}>)',
    f'- [Weekly Questions](<{main.export_weekly_markdown(question_data)}>)',
    f'- [Questions By Code Length](<{main.export_code_length_markdown(question_data)}>)',
    f'- [Questions By Recent](<{main.export_recent_markdown(question_data)}>)',
]

main.export_difficulty_markdowns(question_data)

# %% [markdown]
# ## Topic markdowns
#
# One page per related topic plus the `Topics.md` overview.

# %%
topic_groupings = main.get_completed_topic_lists(question_data, question_details)
overview_path, topic_links = main.export_topic_markdowns(question_data, topic_groupings)
additional_sorts.append(f'- [Grouped by Topic](<{overview_path}>)')

# %% [markdown]
# ## Primary README

# %%
df_questions = main.question_dataframe(question_data, include_markdown_folder=True)
main.export_primary_readme(df_questions,
                           additional_sorts=additional_sorts,
                           topic_links=topic_links)
df_questions.head()

# %% [markdown]
# ## Save modification history

# %%
if not NO_RECORD :
    main.save_file_times(file_latest_times)

print(f'{len(reprocess_markdown)} question markdowns updated/added')
